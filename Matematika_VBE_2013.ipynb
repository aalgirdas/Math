# %% [markdown]
# # **2013 metų matematikos valstybinio brandos egzamino užduotys ir sprendimai.**
#
# #*Pagrindinis šio dokumento tikslas parodyti kaip išspręsti matematikos valstybinio brandos egzamino užduotis naudojant  <b><font color='red'>WolframAlpha</font></b>  dirbtinio intelekto sistemą.*
#
# <br/><br/><br/><br/>

# %% [markdown]
# >>![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# >[wolframalpha nuoroda visoms 5 funkcijoms](https://www.wolframalpha.com/input?i=sqrt%28x%29+%2C+log4%28x%29+%2C+2%5Ex+%2C+x%5E3+%2C+1%2Fx)
#
# > **Kaip matome atsakymas**  **A**
#
# <hr>
# <br/><br/><br/><br/>

# %% [markdown]
# >>![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# > WolfraAlpha gali padėti jei paklausime sistemos kas yra didėjančioji funkcija .  [wolframalpha nuoroda](https://www.wolframalpha.com/input?i=what+is+strictly+increasing+function)
#
#
# > **Atsakymas**  **B**
#
# <hr>
# <br/><br/><br/><br/>

# %% [markdown]
# >>![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# > WolfraAlpha gali padėti jei paklausime sistemos paskaičiuoti modą, medianą ir vidurkį su kiekvienu iš variantų. Toliau pateiksiu pavyzdžius kaip paskaičiuoti modą, medianą ir vidurkį su teisingu atsakymu D t.y 80.  Kodėl verta tikrinti nuo 80? Mediana sako, kad reikia surasti vidurinį elementą, moda, kad dažniausiai pasikartojanį tad ir pradedme tikrinti nuo 80 ir iškarto pataikome.
#
# >[wolframalpha modai](https://www.wolframalpha.com/input?i=mode+72%2C80%2C82%2C86%2C80)
#
# >[wolframalpha medianai](https://www.wolframalpha.com/input?i=median+72%2C80%2C82%2C86%2C80)
#
# >[wolframalpha vidurkiui](https://www.wolframalpha.com/input?i=mean+72%2C80%2C82%2C86%2C80)
#
#
# > **Atsakymas**  **D**
#
# <hr>
# <br/><br/><br/><br/>

# %% [markdown]
# >>![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# > Žiūrime kur kertasi funkcijų grafikai. Matome, kad trijuose taškuose. WolfraAlpha gali padėti jei paprašysime surasti sprendinius lygties $sin(x)=cos(x)$.
#
# >[wolframalpha sprendimas](https://www.wolframalpha.com/input?i=+sin%28x%29%3Dcos%28x%29+%2C+0+degrees<x<450+degrees)
#
#
#
# > **Atsakymas**  **B**
#
# <hr>
# <br/><br/><br/><br/>

# %% [markdown]
# >>![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# > Šešiakampės piramidės pagrindas turi 6 briaunas ir 6 viršūnes. Iš kiekvienos pagrindo viršūnės išeina po vieną briauną, gauname iš viso 12 briaunų. Reiškia piramidė yra septinkampė.
#
# >[wolframalpha sprendimas](https://www.wolframalpha.com/input?i=+pyramid+with+7+vertices) Arba kita [wolframalpha užklausa](https://www.wolframalpha.com/input?i=hexagonal+pyramid)
#
#
#
# > **Atsakymas**  **B**
#
# <hr>
# <br/><br/><br/><br/>

# %% [markdown]
# >>![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# > Aritmetinės progresijos formulė $a_n=a_1+d(n-1)$
#
# > Įsistatome į $a_5 + a_n  = a_2 + a_{10}$. Gauname $a1 + 4d+ a1+ d(n-1) = a1 + d + a1 + 9d$
#
# >[wolframalpha sprendimas](https://www.wolframalpha.com/input?i=a1+%2B+4d%2B+a1%2B+d%28n-1%29+%3D+a1+%2B+d+%2B+a1+%2B+9d)
#
#
#
# > **Atsakymas**  **C**
#
# <hr>
# <br/><br/><br/><br/>

# %% [markdown]
# >>![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# >  $10^8=(10^4)^2$ . Sekantis skaičius $(n+1)^2=(10^4+1)^2$
#
#
# >*wolframalpha čia mums nepadės :)*
#
#
#
# > **Atsakymas**  **D**
#
# <hr>
# <br/><br/><br/><br/>

# %% [markdown]
# >>![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# > Kadangi logaritmo bazė mažiau už 1 tai keičiam nelygybės ženklą nuimdami logaritmą. Ir nepamirštame , kad x turi būti teigiamas. \begin{cases} 100>x \\ x>0 \end{cases}
#
# >[wolframalpha sprendimas](https://www.wolframalpha.com/input?i=log%280.01%2C100%29<log%280.01%2Cx%29)
#
#
#
# > **Atsakymas**  **D**
#
# <hr>
# <br/><br/><br/><br/>

# %% [markdown]
# >>![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# > x modulis reiškia simetriją y ašieš atžvilgiu.Be to funkcija didėja. Tad E
#
# >[wolframalpha sprendimas tiesiog nubrėžiant grafiką](https://www.wolframalpha.com/input?i=2%5Eabs%28x%29)
#
#
#
# > **Atsakymas**  **E**
#
# <hr>
# <br/><br/><br/><br/>

# %% [markdown]
# >>![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# > wolframalpha duoda sprendimą jei įvesime duotas 2 lygtis , o $xyz$ vertę pažymėsime  atskiru kintamuoju, pavyzdžiui $a$. Analitinis sprendimas būtų $xyz=a$ tada $x^2yz^3 \cdot xy^2 = x^3y^3z^3=(xyz)^3=a^3=7^3 \cdot 7^9 = (7^4)^3 \rightarrow a=7^4 $
#
# >[wolframalpha sprendimas](https://www.wolframalpha.com/input?i=x%5E2*y*z%5E3+%3D+7%5E3+%3B+x*y2%3D7%5E9+%3B+x*y*z+%3Da+)
#
#
#
# > **Atsakymas**  **A**
#
# <hr>
# <br/><br/><br/><br/>

# %% [markdown]
# >>![Untitled.png](data:image/png;base64,...)

# %% [markdown]
#  >Tašką įsistatome į duotąją funkciją. $a^2=\frac{4}{9} → a=\frac{2}{3}$
#
#
#  >[wolframalpha sprendimas](https://www.wolframalpha.com/input?i=a%5E2%3D%5Cfrac%7B4%7D%7B9%7D)
#
#
#
# > **Atsakymas**  **D**
#
# <hr>
# <br/><br/><br/><br/>

# %% [markdown]
# >>![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# > Nepamirštame, kad duota sudėtinė funkcija. $h(x)=x^{10}+1$ $f(x)=h(x)^{10}$ Tai išvestinės ieškome kaip sudėtinės funkcijos.
#
#
#  >[wolframalpha sprendimas](https://www.wolframalpha.com/input?i=derivative+%28x%5E10%2B1%29%5E10)
#
#
#
# > **Atsakymas**  **C**
#
# <hr>
# <br/><br/><br/><br/>

# %% [markdown]
# #II dalis

# %% [markdown]
# >>![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# > Tiesiog paskaičiuojame išvestinę ir įstatome $x=\sqrt{x}$ .
#
#  >[wolframalpha sprendimas](https://www.wolframalpha.com/input?i=derivative+2%5E1%2F2+x%5E2+%2B+2%5E1%2F2+%3B+x%3D+2%5E1%2F2)
#
#
# > **Atsakymas**  **4**
#
# <hr>
# <br/><br/><br/><br/>

# %% [markdown]
# >>![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# > Po pirmų metų liko tik $80\%$, po antrų $80\%$ nuo to kas buvo po pirmų ir taip pat trečiais metais  $80\%$ nuo to kas buvo po antrų. Tad $80000 \cdot (0.8)^3=40960%$
#
# >[wolframalpha galime pasinaudoti tik kaip kalkuliatoriumi](https://www.wolframalpha.com/input?i=80000*%280.8%29%5E3)
#
# >[Bet wolframalpha turi ir paruoštą įvedimą procentų uždaviams](https://www.wolframalpha.com/input?i=80000+-+20%25++-+20%25++-+20%25)
#
#
#
# > **Atsakymas**  **40960**
#
# <hr>
# <br/><br/><br/><br/>

# %% [markdown]
# >>![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# > Aišku, kad norime skaitiklis būtų kuo didesnis ir todėl $a = 10, b = 10$ , o vardiklis kuo mažesnis ir todėl $c=1$. Tada $\frac{a+b}{c}  = \frac{10+10}{1}=20$
#
# > Suformuoti šį uždavinį wolframalpha sistemai sunkiau negu jį išspręsti ant lapo popieriaus.
# >[wolframalpha sprendimas tinka daugiau studentams negu moksleiviams](https://www.wolframalpha.com/input?i=maximize++%28a%2Bb%29%2Fc+in++0+%3C+a+%3C11+%2C+0+%3C+b+%3C11+%2C+0+%3C+c+%3C11+%2C+a+mod+1+%3D+0%2C+b+mod+1+%3D+0+%2C+c+mod+1+%3D+0)
#
#
# > **Atsakymas**  **20**
#
# <hr>
# <br/><br/><br/><br/>

# %% [markdown]
# >>![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# > Nepamirškime $\lg$ reiškia $\log_{10}$ Tada $1000^{\frac{1}{6}\lg4}=(10^3)^{\frac{1}{6}\lg4}=10^{\frac{1}{2}\lg4}=10^{lg2}=2$
#
# >[wolframalpha irgi duoda tą patį atsakymą](https://www.wolframalpha.com/input?i=1000%5E%28%281%2F6%29lg4%29)
#
#
# > **Atsakymas**  **2**
#
# <hr>
# <br/><br/><br/><br/>

# %% [markdown]
# >>![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# >Geometrijos uždaviniai gan sunkūs dirbtinio intelekto sistemoms. WolframAlpha kol kas nelabai mums gali padėti nor moksleiviai išsprendžia gan nesunkiai. $AB = 4$ tai $D$ $x$ kordinatė $-2$ ; $AD = 3$ tai $D$ $y$ kordinatė $1.5$
#
#
# > **Atsakymas**  **D(-2 ; 1.5)**
#
# >Pastaba: Geometrijos uždavinių sprendime gali padėti [geogebra](https://www.geogebra.org/calculator) ARBA [symbolab](https://www.symbolab.com)
#
# <hr>
# <br/><br/><br/><br/>

# %% [markdown]
# >>![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# > Matome du trikampius. ABD plotas $S_{ABD}=\frac{5*12}{2}=30$ . Trikampio BCD Plotas: 1) paskaičiuojame BD: $BD=\sqrt{12^2+5^2}=13$ 2) Trikampio BCD aukštinė $13 \cdot sin(60^\circ)=\frac{13\sqrt{3}}{2}$ 3) Trikampio BCD plotas $S_{ABD}=13 \cdot \frac{13\sqrt{3}}{2} \cdot \frac{1}{2} = \frac{169\sqrt{3}}{4}$
#
# > Abu plotus sudedame ir gauname atsakymą $S_{ABCD}=30 + \frac{169\sqrt{3}}{4}=\frac{120+169\sqrt{3}}{4}$
#
# >**WolframAlpha** čia mums gali padėti jei mes paklausime kokie pirmo ir antro trikampio plotai.
#
# >[wolframalpha ABD plotas](https://www.wolframalpha.com/input?i=right+angle+triangle+with+sides+5+and+12)
#
# >[wolframalpha BCD Plotas](https://www.wolframalpha.com/input?i=equilateral+triangle+side+13)
#
#
# > **Atsakymas**  **$\frac{120+169\sqrt{3}}{4}$**
#
# <hr>
# <br/><br/><br/><br/>

# %% [markdown]
# >>![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# >  $P(A)=0.7$ bei $P(B)=0.55$. $P(A ∩ B)=0.7 \cdot 0.55 = 0.385$  $P(A ∪ B) = P(A)+P(B)- P(A ∩ B)=0.865$
#
# > Kitas sprendimas. Tikimybė, kad nėra knygos A  $P(\bar A)=0.3$ , kad nėra knygos B $P(\bar B)=0.45$. Tikimybė, kad bus bent vienoje lygi 1 minus, kad nebus nei vienoje $P(A ∪ B)= 1 - P(\bar A)P(\bar B)=0.865$
#
#
# >[wolframalpha sprendimas](https://www.wolframalpha.com/input?i=probability+of+the+union+of+two+events&assumption=%7B"FS"%7D+->+%7B%7B"TwoUnionProbabilityWithIndependence"%2C+"PAuB"%7D%7D&assumption="FSelect"+->+%7B%7B"TwoUnionProbabilityWithIndependence"%7D%7D&assumption=%7B"F"%2C+"TwoUnionProbabilityWithIndependence"%2C+"PA"%7D+->"0.7"&assumption=%7B"F"%2C+"TwoUnionProbabilityWithIndependence"%2C+"PB"%7D+->"0.55")
#
#
#
# > **Atsakymas**  **$0.865$**
#
# <hr>
# <br/><br/><br/><br/>

# %% [markdown]
# >>![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# > Vektoriai yra statmeni tad jų skaliarinė sandauga lygi nuliui. $(\vec a + 2 \vec b) \cdot (\vec a - 2 \vec b)= |\vec a|^2 - 2 \vec a \vec b +  2 \vec a \vec b - 4|\vec b|^2=0$ Iš čia gauname $4|\vec b|^2=|\vec a|^2=25$ Tad $|\vec b|^2=\frac{25}{4}$ Ir  $|\vec b|=\frac{5}{2}$
#
#
# >[wolframalpha sprendimas gaunamas užrašius vectorių daugybą kaip algebros lygtį ir paimant teigiamą atsakymą](https://www.wolframalpha.com/input?i=%28a%2B2b%29%28a-2b%29+%3D+0+%3B+a+%3D5+)
#
#
#
# > **Atsakymas**  **$\frac{5}{2}$**
#
# <hr>
# <br/><br/><br/><br/>

# %% [markdown]
# >>![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# > Perašom šaknis naudodami laipsnius . $(4-2\sqrt{3})^{1/6} (1+\sqrt{3})^{1/3}(4)^{1/3}=(4-2\sqrt{3})^{1/6} (1+\sqrt{3})^{2/6}(4)^{2/6}= \Big((4-2\sqrt{3}) (1+\sqrt{3})^2(4)^2 \Big )^{1/6}=\Big(64 \Big )^{1/6}=2$
#
#
# >[wolframalpha sprendimas](https://www.wolframalpha.com/input?i=%284-2%5Csqrt%7B3%7D%29%5E%7B1%2F6%7D+%281%2B%5Csqrt%7B3%7D%29%5E%7B1%2F3%7D%284%29%5E%7B1%2F3%7D)
#
#
#
# > **Atsakymas**  **$2$**
#
# <hr>
# <br/><br/><br/><br/>

# %% [markdown]
# >>![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# > Pamėginame paskaičiuoti kampus.  $ \angle BAC = 45^\circ $ nes $ \angle BOC = 90^\circ $. $ \angle AOC = 135^\circ $ nes $ AO=OC=1$. $\Delta AOC$ sudaro pusę mūsų figūros ploto. Iš formulyno duodamo egzamino metu pasiimame trikampio ploto formulę $S_{\Delta AOC}=|AO|\cdot|OC| \cdot \sin{(\angle AOC)} = \frac{\sqrt 2}{4} $
#
# > Tada $S_{ABOC}=2 \cdot S_{\Delta AOC} = \frac{\sqrt 2}{2}  $
#
#
# >[wolframalpha sprendimas $S_{\Delta AOC}$](https://www.wolframalpha.com/input?i=side+angle+side+triangle+with+1%2C+135+degees++%2C1)
#
#
#
# > **Atsakymas**  **$\frac{\sqrt 2}{2}$**
#
# <hr>
# <br/><br/><br/><br/>

# %% [markdown]
# >>![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# > Apskritimo spindulys bus pusė skesmens $|AO|=|OB|=\frac{|AD|+|DB|}{2}=6.5$ Tad $|CD|=\sqrt{|CO|^2-|DO|^2}=\sqrt{6.5^2-2.5^2}=6$
#
#
#
# >[wolframalpha gali padėti tik kaip kalkuliatorius](https://www.wolframalpha.com/input?i=%5Csqrt%7B6.5%5E2-2.5%5E2%7D)
#
#
#
# > **Atsakymas**  **$6$**
#
# <hr>
# <br/><br/><br/><br/>

# %% [markdown]
# >>![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# >Šis uždavinys man pasirodė keistas. Klausia kiek didenės koncentracijos tirpalo reikia pripilti į mažesnės koncetracijos tirpalą, kad gauti kuo didesnę koncentraciją. Pilame kiek tik galime. Kadangi 5 litrų talpoje liko 3 litrai laisvi, tai juos ir užpildome.
#
# > **Atsakymas**  **$3$**
#
# >Pastaba: Uždavinio sudarytojai tikisi, kad moksleivis sudarys lygtį $f(x)=\frac{0.15 \cdot 2 + 0.2 \cdot x}{x+2}$. Tada reikia paskaičiuoti išvestinę ir ją prilyginti 0. Pamačius, kad išvestinė niekada nelygi 0 ir teigiama (reiškia funkcija didėja) paimti maksimaliai galimą x reikšme t.y. 3.
#
# >[wolframalpha sprendimas](https://www.wolframalpha.com/input?i=%280.15+*+2+%2B+0.2+*+x%29%2F%28x%2B2%29+x+range+from+0+to+3)
#
#
# <hr>
# <br/><br/><br/><br/>

# %% [markdown]
# >>![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# >$\sin(x)$ maksimali verė 1 , funkcijos $\sin(x)+a$ maksimali verė 4 , tai reiškia $a=3$
#
# > **Atsakymas**  **$3$**
#
#
# >[wolframalpha sprendimas](https://www.wolframalpha.com/input?i=2%3Dsin%28-pi%2F2%29%2Ba)
#
#
# <hr>
# <br/><br/><br/><br/>

# %% [markdown]
# >>![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# >$f'(x)=tg(\alpha)=\cos(x)$ ; $f'(\pi)=\cos(\pi)=-1$ Tada $tg(\alpha)=-1 \rightarrow \alpha = 135^\circ $
#
# > **Atsakymas**  **$135^\circ$**
#
#
# >[wolframalpha liestinės lygtis](https://www.wolframalpha.com/input?i=tangent+to+sin%28x%29%2B4+at+x%3Dpi) duoda -1 prie x.
#
# >[wolframalpha kampas](https://www.wolframalpha.com/input?i=solve++tan%28x%29%3D-1+for+0%3Cx%3Cpi++)
#
#
#
# <hr>
# <br/><br/><br/><br/>

# %% [markdown]
# >>![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# >$S=  \int_{\frac{-pi}{2}}^\frac{pi}{2}(\sin(x) + 3) \,dx  = -\cos(x) + 3x |_{\frac{-pi}{2}}^\frac{pi}{2} =3\pi $
#
#
# >[wolframalpha atsakymas](https://www.wolframalpha.com/input?i=find+the+area+between+sinx%2B3+and+0+from+-pi%2F2+to+pi%2F2)
#
# > **Atsakymas**  **$3\pi$**
#
#
#
# <hr>
# <br/><br/><br/><br/>

# %% [markdown]
# #**26.**
#
# >>Raskite didžiausią sveikąjį lygties $\sqrt{x^2-4x+12}=3$ sprendinį.

# %% [markdown]
# >Pakeliam kvadratu ir išsprendžiam kvadratinę lygtį
#
#
# >[wolframalpha atsakymas](https://www.wolframalpha.com/input?i=%5Csqrt%7Bx%5E2-4x%2B12%7D%3D3)
#
# > **Atsakymas**  **$3$**
#
#
#
# <hr>
# <br/><br/><br/><br/>

# %% [markdown]
# >>![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# >
#
#
# >[wolframalpha sprendimas 1 žingsnis](https://www.wolframalpha.com/input?i=regular+triangular+pyramid++height+%3D2sqrt%283%29+%2C+volume+%3D8++)
#
# >[wolframalpha sprendimas 2 žingsnis](https://www.wolframalpha.com/input?i=equilateral+triangle+area+%3D4sqrt%283%29)
#
#
#
# > **Atsakymas**  **$2\sqrt{3}$**
#
# <hr>
# <br/><br/><br/><br/>

# %% [markdown]
# #**28**.
#
# >>Iš skaitmenų $0, 3, 5$ sudaromi visi galimi triženkliai skaičiai. Skaičiaus skaitmenys gali kartotis (pvz., $555, 300, 303, ...$).
#
# >> **28.1.** Kiek tokių triženklių skaičių galima sudaryti?

# %% [markdown]
# > Pirmas skaitmuo gali būti 3 arba 5, antras $0, 3, 5$ ir trečias $0, 3, 5$ Tad $2 \cdot 3 \cdot 3 = 18$
#
#
# >[wolframalpha kai 0 priekyje leidžiamas](https://www.wolframalpha.com/input?i=Tuples%5B%7B0%2C+3%2C+5%7D%2C+3%5D). Atmetus variantus su nuliu priekyje gauname kad liko 18. Šis linkas demonstruoja, kad WolfraAlpha supranta Mathemetica kalba parašytas instrukcijas.
#
#
#
# > **Atsakymas**  **$18$**
#
# <hr>
# <br/><br/><br/><br/>

# %% [markdown]
# >>**28.2.** Apskaičiuokite tikimybę, kad iš sudarytų skaičių atsitiktinai paimtas skaičius dalijasi iš 3.

# %% [markdown]
# > Iš viso yra 18 skaičių. Skaičiai , kurie dalinasi 3 yra šie $333, 303, 330, 300, 555$ Tad tikimybė $P=\frac{5}{18}$
#
#
#
# > **Atsakymas**  **$\frac{5}{18}$**
#
# <hr>
# <br/><br/><br/><br/>

# %% [markdown]
# #**29.**
#
# >>Šeši darbuotojai gavo dovanų 6 bilietus į teatrą, keturiuose iš jų vietos buvo nurodytos pirmoje eilėje. Darbuotojai dalijasi bilietus atsitiktinai juos traukdami. Kokia tikimybė, kad dviejų iš pirmų trijų ištrauktų bilietų vietos bus pirmoje eilėje?

# %% [markdown]
# > Turime dviejų tipų bilietus t.y. 2 bilietai ne pirmoje eilėje (pažymėkime juos 0) ir mus dominantys 4 bilietai pirmoje eilėje (pažymėkime juos 1). Taigi turime rinkinį iš elementų $\{0,0,1,1,1,1\}$. Mums tinkantys traukimai yra šie $(110)(101)(011)$. Tikimybė $P(110)=\frac{4}{6}\frac{3}{5}\frac{2}{4}=\frac{1}{5}$. $P(101)=\frac{4}{6}\frac{2}{5}\frac{3}{4}=\frac{1}{5}$. $P(011)=\frac{2}{6}\frac{4}{5}\frac{3}{4}=\frac{1}{5}$.
#
# > Sudedame visas 3 tikimybes ir gayname atsakymą $P(A)=\frac{3}{5}$.
#
#
# > **Atsakymas**  **$\frac{3}{5}$**
#
# Pastaba: WolfraAlpha čia padėti nelabai gali. [Ji gali spręsti tik tokius tekstinius uždavinius](https://www.wolframalpha.com/examples/mathematics/elementary-math/mathematical-word-problems). Pasirodė nauja dirbtinio intelekto sistema [ChatGPT](https://openai.com/blog/chatgpt/) , reikėtų gal pamėginti dirbti su ja. Ji gali spręsti tekstinius matematikos uždavinius, tačiau dažnai kaip ir WolfraAlpha korektiškai nesupranta sąlygos.
#
# <hr>
# <br/><br/><br/><br/>

# %% [markdown]
# >>![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# >*WolfraAlpha čia padėti nelabai gali.*
#
# > Apibrėžtinis keturkampis turi tokią savybę ∠A+∠C=∠B+∠D=180
#
# > Duota $CB \cdot CD = AB \cdot AD $
#
# > Tada $S_{BSC}=\frac{1}{2} CB \cdot CD \cdot \sin(∠C)=\frac{1}{2} CB \cdot CD \cdot \sin(180-∠A)=\frac{1}{2} CB \cdot CD \cdot \sin(∠A)=\frac{1}{2} AB \cdot AD \cdot \sin(∠A) = $S_{ABD}=20$
#
#
# > **Atsakymas**  **$20$**
#
#
# <hr>
# <br/><br/><br/><br/>

# %% [markdown]
# >>![Untitled.png](data:image/png;base64,...)

# %% [markdown]
# > Tebūnie pirmojo dviratininko greitis $v_1 =12$ , antro $v_2 =10$
#
# > Trečiasis pavijo antrąjį (reiškia nuvažiuoti keliai vienodi ir trečias važiavo viena valanda trumpiau nei antras) $v_2 \cdot t_2  =  v_3 \cdot (t_2 - 1) $
#
# >o praėjus dar 2 valandoms – pirmąjį dviratininką $v_1 \cdot (t_2 + 1 + 2)  =  v_3 \cdot (t_2 - 1 + 2) => v_1 \cdot (t_2 + 3)  =  v_3 \cdot (t_2 + 1) $
#
#
# >[wolframalpha lengvai išprendžia šią lygčių sistemą](https://www.wolframalpha.com/input?i=v1+%3D12+%3B+v2+%3D10+%3B+v2+*+t2++%3D++v3+*+%28t2+-+1%29+%3B++v1+*+%28t2+%2B+3%29++%3D++v3+*+%28t2+%2B+1%29)
#
#
# > **Atsakymas**  **$20$**
#
#
# <hr>
# <br/><br/><br/><br/>
